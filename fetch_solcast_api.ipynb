# %%
import requests
import datetime

# %%
import requests

url = "https://api.solcast.com.au/world_radiation/estimated_actuals??format=json"


querystring = {"api_key":"bmDCPHfGBni1xCX8uBxuGJmRhRLbLaVC","longitude":"-0.127758","latitude":"51.507351", "hours":"168"}

headers = {'Content-Type': 'application/json'}

response = requests.request("GET", url, headers=headers, params=querystring)
print(response)
# Out:
# <Response [200]>

# %%
import requests
url = 'https://api.solcast.com.au/world_radiation/forecasts?latitude=-33.865143&longitude=151.209900'
querystring = {"api_key" : apikey['key']}
res = requests.get(url, params=querystring, headers={'Content-Type': 'application/json'})
data = res.json()
forecast = data["forecasts"][0]["ghi"]

print('forecasts: {} degree'.format(forecast))
# Out:
# forecastss: 0 dgree

# %%
import configparser
config = configparser.ConfigParser()
if not config.has_section("APIKEY"):
    config.add_section("APIKEY")
    config.set("APIKEY", "key", "bmDCPHfGBni1xCX8uBxuGJmRhRLbLaVC")

with open("solcast_test.ini", 'w') as configfile:
    config.write(configfile)

# %%
config = configparser.ConfigParser()		
config.read("solcast_test.ini")
apikey = config['APIKEY']

# %%
apikey['key']
# Out:
# 'bmDCPHfGBni1xCX8uBxuGJmRhRLbLaVC'

# %%
import solcast
response = solcast.get_radiation_forecasts(-35, 149, apikey['key'])
response_2 = solcast.radiation_estimated_actuals(-35, 149, apikey['key'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-21548b5331e7> in <module>
#       1 import solcast
#       2 response = solcast.get_radiation_forecasts(-35, 149, apikey['key'])
# ----> 3 response_2 = solcast.radiation_estimated_actuals(-35, 149, apikey['key'])
#
# TypeError: 'module' object is not callable

# %%
response_2.forecasts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-005135cfb28f> in <module>
# ----> 1 response_2.forecasts
#
# NameError: name 'response_2' is not defined

# %%
response.forecasts
# Out:
# [{'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 131,
#   'azimuth': -91,
#   'cloud_opacity': 65,
#   'period_end': datetime.datetime(2021, 7, 15, 18, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 125,
#   'azimuth': -87,
#   'cloud_opacity': 61,
#   'period_end': datetime.datetime(2021, 7, 15, 18, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 119,
#   'azimuth': -83,
#   'cloud_opacity': 32,
#   'period_end': datetime.datetime(2021, 7, 15, 19, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 113,
#   'azimuth': -79,
#   'cloud_opacity': 20,
#   'period_end': datetime.datetime(2021, 7, 15, 19, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 107,
#   'azimuth': -75,
#   'cloud_opacity': 22,
#   'period_end': datetime.datetime(2021, 7, 15, 20, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 7,
#   'zenith': 101,
#   'azimuth': -71,
#   'cloud_opacity': 35,
#   'period_end': datetime.datetime(2021, 7, 15, 20, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 7,
#   'zenith': 95,
#   'azimuth': -67,
#   'cloud_opacity': 47,
#   'period_end': datetime.datetime(2021, 7, 15, 21, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 3,
#   'ghi90': 8,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 6,
#   'dhi': 3,
#   'air_temp': 7,
#   'zenith': 90,
#   'azimuth': -63,
#   'cloud_opacity': 62,
#   'period_end': datetime.datetime(2021, 7, 15, 21, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 18,
#   'ghi90': 45,
#   'ghi10': 3,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 47,
#   'dhi': 18,
#   'air_temp': 7,
#   'zenith': 85,
#   'azimuth': -59,
#   'cloud_opacity': 72,
#   'period_end': datetime.datetime(2021, 7, 15, 22, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 39,
#   'ghi90': 101,
#   'ghi10': 7,
#   'ebh': 1,
#   'dni': 4,
#   'dni10': 0,
#   'dni90': 89,
#   'dhi': 39,
#   'air_temp': 8,
#   'zenith': 79,
#   'azimuth': -54,
#   'cloud_opacity': 73,
#   'period_end': datetime.datetime(2021, 7, 15, 22, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 61,
#   'ghi90': 153,
#   'ghi10': 11,
#   'ebh': 1,
#   'dni': 4,
#   'dni10': 0,
#   'dni90': 116,
#   'dhi': 60,
#   'air_temp': 8,
#   'zenith': 75,
#   'azimuth': -49,
#   'cloud_opacity': 73,
#   'period_end': datetime.datetime(2021, 7, 15, 23, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 79,
#   'ghi90': 202,
#   'ghi10': 15,
#   'ebh': 1,
#   'dni': 3,
#   'dni10': 0,
#   'dni90': 111,
#   'dhi': 79,
#   'air_temp': 7,
#   'zenith': 70,
#   'azimuth': -43,
#   'cloud_opacity': 74,
#   'period_end': datetime.datetime(2021, 7, 15, 23, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 97,
#   'ghi90': 243,
#   'ghi10': 19,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 106,
#   'dhi': 96,
#   'air_temp': 7,
#   'zenith': 66,
#   'azimuth': -37,
#   'cloud_opacity': 74,
#   'period_end': datetime.datetime(2021, 7, 16, 0, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 108,
#   'ghi90': 272,
#   'ghi10': 22,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 99,
#   'dhi': 107,
#   'air_temp': 7,
#   'zenith': 63,
#   'azimuth': -30,
#   'cloud_opacity': 75,
#   'period_end': datetime.datetime(2021, 7, 16, 0, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 111,
#   'ghi90': 288,
#   'ghi10': 24,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 84,
#   'dhi': 110,
#   'air_temp': 6,
#   'zenith': 60,
#   'azimuth': -23,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 16, 1, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 105,
#   'ghi90': 290,
#   'ghi10': 26,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 62,
#   'dhi': 104,
#   'air_temp': 7,
#   'zenith': 58,
#   'azimuth': -15,
#   'cloud_opacity': 79,
#   'period_end': datetime.datetime(2021, 7, 16, 1, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 93,
#   'ghi90': 279,
#   'ghi10': 27,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 46,
#   'dhi': 92,
#   'air_temp': 7,
#   'zenith': 57,
#   'azimuth': -7,
#   'cloud_opacity': 83,
#   'period_end': datetime.datetime(2021, 7, 16, 2, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 79,
#   'ghi90': 262,
#   'ghi10': 27,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 33,
#   'dhi': 79,
#   'air_temp': 7,
#   'zenith': 57,
#   'azimuth': 1,
#   'cloud_opacity': 85,
#   'period_end': datetime.datetime(2021, 7, 16, 2, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 73,
#   'ghi90': 246,
#   'ghi10': 27,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 26,
#   'dhi': 73,
#   'air_temp': 8,
#   'zenith': 57,
#   'azimuth': 10,
#   'cloud_opacity': 86,
#   'period_end': datetime.datetime(2021, 7, 16, 3, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 74,
#   'ghi90': 234,
#   'ghi10': 25,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 27,
#   'dhi': 74,
#   'air_temp': 7,
#   'zenith': 59,
#   'azimuth': 18,
#   'cloud_opacity': 85,
#   'period_end': datetime.datetime(2021, 7, 16, 3, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 79,
#   'ghi90': 222,
#   'ghi10': 24,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 29,
#   'dhi': 78,
#   'air_temp': 7,
#   'zenith': 61,
#   'azimuth': 25,
#   'cloud_opacity': 83,
#   'period_end': datetime.datetime(2021, 7, 16, 4, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 82,
#   'ghi90': 205,
#   'ghi10': 21,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 34,
#   'dhi': 81,
#   'air_temp': 6,
#   'zenith': 64,
#   'azimuth': 33,
#   'cloud_opacity': 79,
#   'period_end': datetime.datetime(2021, 7, 16, 4, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 79,
#   'ghi90': 178,
#   'ghi10': 18,
#   'ebh': 1,
#   'dni': 3,
#   'dni10': 0,
#   'dni90': 37,
#   'dhi': 78,
#   'air_temp': 6,
#   'zenith': 68,
#   'azimuth': 39,
#   'cloud_opacity': 78,
#   'period_end': datetime.datetime(2021, 7, 16, 5, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 67,
#   'ghi90': 143,
#   'ghi10': 14,
#   'ebh': 1,
#   'dni': 3,
#   'dni10': 0,
#   'dni90': 39,
#   'dhi': 66,
#   'air_temp': 6,
#   'zenith': 72,
#   'azimuth': 45,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 16, 5, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 50,
#   'ghi90': 102,
#   'ghi10': 9,
#   'ebh': 1,
#   'dni': 4,
#   'dni10': 0,
#   'dni90': 33,
#   'dhi': 49,
#   'air_temp': 4,
#   'zenith': 76,
#   'azimuth': 51,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 16, 6, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 29,
#   'ghi90': 58,
#   'ghi10': 6,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 24,
#   'dhi': 29,
#   'air_temp': 4,
#   'zenith': 81,
#   'azimuth': 56,
#   'cloud_opacity': 75,
#   'period_end': datetime.datetime(2021, 7, 16, 6, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 9,
#   'ghi90': 19,
#   'ghi10': 2,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 6,
#   'dhi': 9,
#   'air_temp': 4,
#   'zenith': 86,
#   'azimuth': 60,
#   'cloud_opacity': 75,
#   'period_end': datetime.datetime(2021, 7, 16, 7, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 92,
#   'azimuth': 65,
#   'cloud_opacity': 75,
#   'period_end': datetime.datetime(2021, 7, 16, 7, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 97,
#   'azimuth': 69,
#   'cloud_opacity': 74,
#   'period_end': datetime.datetime(2021, 7, 16, 8, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 103,
#   'azimuth': 73,
#   'cloud_opacity': 74,
#   'period_end': datetime.datetime(2021, 7, 16, 8, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 109,
#   'azimuth': 77,
#   'cloud_opacity': 74,
#   'period_end': datetime.datetime(2021, 7, 16, 9, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 115,
#   'azimuth': 80,
#   'cloud_opacity': 75,
#   'period_end': datetime.datetime(2021, 7, 16, 9, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 121,
#   'azimuth': 84,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 16, 10, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 127,
#   'azimuth': 88,
#   'cloud_opacity': 78,
#   'period_end': datetime.datetime(2021, 7, 16, 10, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 133,
#   'azimuth': 93,
#   'cloud_opacity': 79,
#   'period_end': datetime.datetime(2021, 7, 16, 11, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 140,
#   'azimuth': 97,
#   'cloud_opacity': 81,
#   'period_end': datetime.datetime(2021, 7, 16, 11, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 146,
#   'azimuth': 103,
#   'cloud_opacity': 83,
#   'period_end': datetime.datetime(2021, 7, 16, 12, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 152,
#   'azimuth': 110,
#   'cloud_opacity': 85,
#   'period_end': datetime.datetime(2021, 7, 16, 12, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 157,
#   'azimuth': 120,
#   'cloud_opacity': 87,
#   'period_end': datetime.datetime(2021, 7, 16, 13, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 162,
#   'azimuth': 135,
#   'cloud_opacity': 89,
#   'period_end': datetime.datetime(2021, 7, 16, 13, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 166,
#   'azimuth': 156,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 14, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 7,
#   'zenith': 167,
#   'azimuth': -175,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 14, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 7,
#   'zenith': 165,
#   'azimuth': -148,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 15, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 160,
#   'azimuth': -129,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 15, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 155,
#   'azimuth': -116,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 16, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 150,
#   'azimuth': -108,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 16, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 144,
#   'azimuth': -101,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 17, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 137,
#   'azimuth': -96,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 17, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 131,
#   'azimuth': -91,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 18, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 125,
#   'azimuth': -87,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 16, 18, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 119,
#   'azimuth': -83,
#   'cloud_opacity': 89,
#   'period_end': datetime.datetime(2021, 7, 16, 19, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 113,
#   'azimuth': -79,
#   'cloud_opacity': 88,
#   'period_end': datetime.datetime(2021, 7, 16, 19, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 107,
#   'azimuth': -75,
#   'cloud_opacity': 87,
#   'period_end': datetime.datetime(2021, 7, 16, 20, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 101,
#   'azimuth': -71,
#   'cloud_opacity': 86,
#   'period_end': datetime.datetime(2021, 7, 16, 20, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 95,
#   'azimuth': -67,
#   'cloud_opacity': 84,
#   'period_end': datetime.datetime(2021, 7, 16, 21, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 90,
#   'azimuth': -63,
#   'cloud_opacity': 83,
#   'period_end': datetime.datetime(2021, 7, 16, 21, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 12,
#   'ghi90': 26,
#   'ghi10': 3,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 6,
#   'dhi': 12,
#   'air_temp': 3,
#   'zenith': 84,
#   'azimuth': -59,
#   'cloud_opacity': 82,
#   'period_end': datetime.datetime(2021, 7, 16, 22, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 28,
#   'ghi90': 61,
#   'ghi10': 8,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 9,
#   'dhi': 28,
#   'air_temp': 3,
#   'zenith': 79,
#   'azimuth': -54,
#   'cloud_opacity': 82,
#   'period_end': datetime.datetime(2021, 7, 16, 22, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 45,
#   'ghi90': 96,
#   'ghi10': 12,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 15,
#   'dhi': 45,
#   'air_temp': 3,
#   'zenith': 75,
#   'azimuth': -49,
#   'cloud_opacity': 81,
#   'period_end': datetime.datetime(2021, 7, 16, 23, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 60,
#   'ghi90': 130,
#   'ghi10': 16,
#   'ebh': 1,
#   'dni': 3,
#   'dni10': 0,
#   'dni90': 15,
#   'dhi': 59,
#   'air_temp': 3,
#   'zenith': 70,
#   'azimuth': -43,
#   'cloud_opacity': 81,
#   'period_end': datetime.datetime(2021, 7, 16, 23, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 74,
#   'ghi90': 161,
#   'ghi10': 19,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 17,
#   'dhi': 73,
#   'air_temp': 3,
#   'zenith': 66,
#   'azimuth': -37,
#   'cloud_opacity': 81,
#   'period_end': datetime.datetime(2021, 7, 17, 0, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 86,
#   'ghi90': 187,
#   'ghi10': 22,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 18,
#   'dhi': 85,
#   'air_temp': 3,
#   'zenith': 63,
#   'azimuth': -30,
#   'cloud_opacity': 81,
#   'period_end': datetime.datetime(2021, 7, 17, 0, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 97,
#   'ghi90': 208,
#   'ghi10': 25,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 18,
#   'dhi': 96,
#   'air_temp': 2,
#   'zenith': 60,
#   'azimuth': -23,
#   'cloud_opacity': 79,
#   'period_end': datetime.datetime(2021, 7, 17, 1, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 107,
#   'ghi90': 226,
#   'ghi10': 26,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 19,
#   'dhi': 106,
#   'air_temp': 2,
#   'zenith': 58,
#   'azimuth': -15,
#   'cloud_opacity': 79,
#   'period_end': datetime.datetime(2021, 7, 17, 1, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 114,
#   'ghi90': 237,
#   'ghi10': 27,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 19,
#   'dhi': 113,
#   'air_temp': 2,
#   'zenith': 57,
#   'azimuth': -7,
#   'cloud_opacity': 79,
#   'period_end': datetime.datetime(2021, 7, 17, 2, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 113,
#   'ghi90': 237,
#   'ghi10': 28,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 19,
#   'dhi': 112,
#   'air_temp': 2,
#   'zenith': 57,
#   'azimuth': 1,
#   'cloud_opacity': 79,
#   'period_end': datetime.datetime(2021, 7, 17, 2, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 102,
#   'ghi90': 223,
#   'ghi10': 27,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 17,
#   'dhi': 101,
#   'air_temp': 2,
#   'zenith': 57,
#   'azimuth': 10,
#   'cloud_opacity': 81,
#   'period_end': datetime.datetime(2021, 7, 17, 3, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 82,
#   'ghi90': 197,
#   'ghi10': 26,
#   'ebh': 1,
#   'dni': 2,
#   'dni10': 0,
#   'dni90': 14,
#   'dhi': 81,
#   'air_temp': 2,
#   'zenith': 59,
#   'azimuth': 18,
#   'cloud_opacity': 84,
#   'period_end': datetime.datetime(2021, 7, 17, 3, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 59,
#   'ghi90': 166,
#   'ghi10': 24,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 8,
#   'dhi': 59,
#   'air_temp': 3,
#   'zenith': 61,
#   'azimuth': 25,
#   'cloud_opacity': 88,
#   'period_end': datetime.datetime(2021, 7, 17, 4, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 43,
#   'ghi90': 139,
#   'ghi10': 21,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 7,
#   'dhi': 43,
#   'air_temp': 3,
#   'zenith': 64,
#   'azimuth': 33,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 17, 4, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 36,
#   'ghi90': 118,
#   'ghi10': 18,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 8,
#   'dhi': 36,
#   'air_temp': 4,
#   'zenith': 67,
#   'azimuth': 39,
#   'cloud_opacity': 90,
#   'period_end': datetime.datetime(2021, 7, 17, 5, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 31,
#   'ghi90': 97,
#   'ghi10': 14,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 9,
#   'dhi': 31,
#   'air_temp': 3,
#   'zenith': 72,
#   'azimuth': 45,
#   'cloud_opacity': 89,
#   'period_end': datetime.datetime(2021, 7, 17, 5, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 30,
#   'ghi90': 78,
#   'ghi10': 9,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 12,
#   'dhi': 30,
#   'air_temp': 3,
#   'zenith': 76,
#   'azimuth': 51,
#   'cloud_opacity': 86,
#   'period_end': datetime.datetime(2021, 7, 17, 6, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 22,
#   'ghi90': 52,
#   'ghi10': 6,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 12,
#   'dhi': 22,
#   'air_temp': 3,
#   'zenith': 81,
#   'azimuth': 56,
#   'cloud_opacity': 82,
#   'period_end': datetime.datetime(2021, 7, 17, 6, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 9,
#   'ghi90': 19,
#   'ghi10': 2,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 6,
#   'dhi': 9,
#   'air_temp': 3,
#   'zenith': 86,
#   'azimuth': 60,
#   'cloud_opacity': 78,
#   'period_end': datetime.datetime(2021, 7, 17, 7, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 92,
#   'azimuth': 65,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 7, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 97,
#   'azimuth': 69,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 8, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 103,
#   'azimuth': 73,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 8, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 109,
#   'azimuth': 77,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 9, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 115,
#   'azimuth': 80,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 9, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 121,
#   'azimuth': 84,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 10, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 127,
#   'azimuth': 88,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 10, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 133,
#   'azimuth': 93,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 11, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 140,
#   'azimuth': 98,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 11, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 146,
#   'azimuth': 103,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 12, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 151,
#   'azimuth': 111,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 12, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 157,
#   'azimuth': 120,
#   'cloud_opacity': 76,
#   'period_end': datetime.datetime(2021, 7, 17, 13, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 162,
#   'azimuth': 135,
#   'cloud_opacity': 75,
#   'period_end': datetime.datetime(2021, 7, 17, 13, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 165,
#   'azimuth': 156,
#   'cloud_opacity': 75,
#   'period_end': datetime.datetime(2021, 7, 17, 14, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 166,
#   'azimuth': -175,
#   'cloud_opacity': 74,
#   'period_end': datetime.datetime(2021, 7, 17, 14, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 164,
#   'azimuth': -148,
#   'cloud_opacity': 74,
#   'period_end': datetime.datetime(2021, 7, 17, 15, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 160,
#   'azimuth': -129,
#   'cloud_opacity': 73,
#   'period_end': datetime.datetime(2021, 7, 17, 15, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 155,
#   'azimuth': -117,
#   'cloud_opacity': 72,
#   'period_end': datetime.datetime(2021, 7, 17, 16, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 149,
#   'azimuth': -108,
#   'cloud_opacity': 71,
#   'period_end': datetime.datetime(2021, 7, 17, 16, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 144,
#   'azimuth': -101,
#   'cloud_opacity': 70,
#   'period_end': datetime.datetime(2021, 7, 17, 17, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 137,
#   'azimuth': -96,
#   'cloud_opacity': 68,
#   'period_end': datetime.datetime(2021, 7, 17, 17, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 131,
#   'azimuth': -91,
#   'cloud_opacity': 67,
#   'period_end': datetime.datetime(2021, 7, 17, 18, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 125,
#   'azimuth': -87,
#   'cloud_opacity': 65,
#   'period_end': datetime.datetime(2021, 7, 17, 18, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 119,
#   'azimuth': -83,
#   'cloud_opacity': 64,
#   'period_end': datetime.datetime(2021, 7, 17, 19, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 113,
#   'azimuth': -79,
#   'cloud_opacity': 62,
#   'period_end': datetime.datetime(2021, 7, 17, 19, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 107,
#   'azimuth': -75,
#   'cloud_opacity': 61,
#   'period_end': datetime.datetime(2021, 7, 17, 20, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 101,
#   'azimuth': -72,
#   'cloud_opacity': 59,
#   'period_end': datetime.datetime(2021, 7, 17, 20, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 95,
#   'azimuth': -68,
#   'cloud_opacity': 56,
#   'period_end': datetime.datetime(2021, 7, 17, 21, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 1,
#   'ghi90': 2,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 1,
#   'air_temp': 4,
#   'zenith': 90,
#   'azimuth': -63,
#   'cloud_opacity': 53,
#   'period_end': datetime.datetime(2021, 7, 17, 21, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 34,
#   'ghi90': 63,
#   'ghi10': 6,
#   'ebh': 2,
#   'dni': 12,
#   'dni10': 0,
#   'dni90': 124,
#   'dhi': 32,
#   'air_temp': 4,
#   'zenith': 84,
#   'azimuth': -59,
#   'cloud_opacity': 50,
#   'period_end': datetime.datetime(2021, 7, 17, 22, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 81,
#   'ghi90': 144,
#   'ghi10': 18,
#   'ebh': 6,
#   'dni': 31,
#   'dni10': 0,
#   'dni90': 404,
#   'dhi': 75,
#   'air_temp': 4,
#   'zenith': 79,
#   'azimuth': -54,
#   'cloud_opacity': 47,
#   'period_end': datetime.datetime(2021, 7, 17, 22, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 132,
#   'ghi90': 229,
#   'ghi10': 34,
#   'ebh': 12,
#   'dni': 44,
#   'dni10': 0,
#   'dni90': 533,
#   'dhi': 120,
#   'air_temp': 4,
#   'zenith': 74,
#   'azimuth': -49,
#   'cloud_opacity': 45,
#   'period_end': datetime.datetime(2021, 7, 17, 23, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 182,
#   'ghi90': 312,
#   'ghi10': 51,
#   'ebh': 21,
#   'dni': 61,
#   'dni10': 0,
#   'dni90': 699,
#   'dhi': 161,
#   'air_temp': 6,
#   'zenith': 70,
#   'azimuth': -43,
#   'cloud_opacity': 43,
#   'period_end': datetime.datetime(2021, 7, 17, 23, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 230,
#   'ghi90': 389,
#   'ghi10': 68,
#   'ebh': 31,
#   'dni': 76,
#   'dni10': 0,
#   'dni90': 777,
#   'dhi': 199,
#   'air_temp': 6,
#   'zenith': 66,
#   'azimuth': -37,
#   'cloud_opacity': 41,
#   'period_end': datetime.datetime(2021, 7, 18, 0, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 273,
#   'ghi90': 449,
#   'ghi10': 83,
#   'ebh': 45,
#   'dni': 99,
#   'dni10': 2,
#   'dni90': 835,
#   'dhi': 228,
#   'air_temp': 6,
#   'zenith': 63,
#   'azimuth': -30,
#   'cloud_opacity': 39,
#   'period_end': datetime.datetime(2021, 7, 18, 0, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 312,
#   'ghi90': 497,
#   'ghi10': 96,
#   'ebh': 58,
#   'dni': 116,
#   'dni10': 2,
#   'dni90': 842,
#   'dhi': 254,
#   'air_temp': 6,
#   'zenith': 60,
#   'azimuth': -23,
#   'cloud_opacity': 37,
#   'period_end': datetime.datetime(2021, 7, 18, 1, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 346,
#   'ghi90': 531,
#   'ghi10': 110,
#   'ebh': 74,
#   'dni': 140,
#   'dni10': 2,
#   'dni90': 855,
#   'dhi': 272,
#   'air_temp': 7,
#   'zenith': 58,
#   'azimuth': -15,
#   'cloud_opacity': 35,
#   'period_end': datetime.datetime(2021, 7, 18, 1, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 372,
#   'ghi90': 551,
#   'ghi10': 119,
#   'ebh': 98,
#   'dni': 180,
#   'dni10': 2,
#   'dni90': 872,
#   'dhi': 274,
#   'air_temp': 8,
#   'zenith': 57,
#   'azimuth': -7,
#   'cloud_opacity': 32,
#   'period_end': datetime.datetime(2021, 7, 18, 2, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 384,
#   'ghi90': 555,
#   'ghi10': 121,
#   'ebh': 104,
#   'dni': 186,
#   'dni10': 2,
#   'dni90': 839,
#   'dhi': 280,
#   'air_temp': 7,
#   'zenith': 56,
#   'azimuth': 1,
#   'cloud_opacity': 31,
#   'period_end': datetime.datetime(2021, 7, 18, 2, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 377,
#   'ghi90': 545,
#   'ghi10': 111,
#   'ebh': 105,
#   'dni': 193,
#   'dni10': 2,
#   'dni90': 856,
#   'dhi': 272,
#   'air_temp': 7,
#   'zenith': 57,
#   'azimuth': 10,
#   'cloud_opacity': 31,
#   'period_end': datetime.datetime(2021, 7, 18, 3, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 351,
#   'ghi90': 520,
#   'ghi10': 89,
#   'ebh': 84,
#   'dni': 159,
#   'dni10': 2,
#   'dni90': 825,
#   'dhi': 267,
#   'air_temp': 7,
#   'zenith': 58,
#   'azimuth': 18,
#   'cloud_opacity': 33,
#   'period_end': datetime.datetime(2021, 7, 18, 3, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 313,
#   'ghi90': 481,
#   'ghi10': 66,
#   'ebh': 69,
#   'dni': 142,
#   'dni10': 0,
#   'dni90': 848,
#   'dhi': 245,
#   'air_temp': 8,
#   'zenith': 61,
#   'azimuth': 25,
#   'cloud_opacity': 35,
#   'period_end': datetime.datetime(2021, 7, 18, 4, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 276,
#   'ghi90': 429,
#   'ghi10': 49,
#   'ebh': 57,
#   'dni': 130,
#   'dni10': 0,
#   'dni90': 828,
#   'dhi': 219,
#   'air_temp': 7,
#   'zenith': 64,
#   'azimuth': 33,
#   'cloud_opacity': 36,
#   'period_end': datetime.datetime(2021, 7, 18, 4, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 240,
#   'ghi90': 364,
#   'ghi10': 44,
#   'ebh': 52,
#   'dni': 133,
#   'dni10': 0,
#   'dni90': 749,
#   'dhi': 188,
#   'air_temp': 7,
#   'zenith': 67,
#   'azimuth': 39,
#   'cloud_opacity': 34,
#   'period_end': datetime.datetime(2021, 7, 18, 5, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 206,
#   'ghi90': 290,
#   'ghi10': 48,
#   'ebh': 55,
#   'dni': 168,
#   'dni10': 0,
#   'dni90': 682,
#   'dhi': 151,
#   'air_temp': 7,
#   'zenith': 71,
#   'azimuth': 45,
#   'cloud_opacity': 29,
#   'period_end': datetime.datetime(2021, 7, 18, 5, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 163,
#   'ghi90': 208,
#   'ghi10': 49,
#   'ebh': 58,
#   'dni': 240,
#   'dni10': 4,
#   'dni90': 632,
#   'dhi': 105,
#   'air_temp': 6,
#   'zenith': 76,
#   'azimuth': 51,
#   'cloud_opacity': 22,
#   'period_end': datetime.datetime(2021, 7, 18, 6, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 105,
#   'ghi90': 123,
#   'ghi10': 38,
#   'ebh': 45,
#   'dni': 265,
#   'dni10': 6,
#   'dni90': 471,
#   'dhi': 60,
#   'air_temp': 6,
#   'zenith': 81,
#   'azimuth': 56,
#   'cloud_opacity': 14,
#   'period_end': datetime.datetime(2021, 7, 18, 6, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 39,
#   'ghi90': 43,
#   'ghi10': 16,
#   'ebh': 13,
#   'dni': 76,
#   'dni10': 6,
#   'dni90': 106,
#   'dhi': 26,
#   'air_temp': 4,
#   'zenith': 86,
#   'azimuth': 60,
#   'cloud_opacity': 9,
#   'period_end': datetime.datetime(2021, 7, 18, 7, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 92,
#   'azimuth': 65,
#   'cloud_opacity': 6,
#   'period_end': datetime.datetime(2021, 7, 18, 7, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 97,
#   'azimuth': 69,
#   'cloud_opacity': 6,
#   'period_end': datetime.datetime(2021, 7, 18, 8, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 103,
#   'azimuth': 73,
#   'cloud_opacity': 6,
#   'period_end': datetime.datetime(2021, 7, 18, 8, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 109,
#   'azimuth': 77,
#   'cloud_opacity': 7,
#   'period_end': datetime.datetime(2021, 7, 18, 9, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 115,
#   'azimuth': 81,
#   'cloud_opacity': 8,
#   'period_end': datetime.datetime(2021, 7, 18, 9, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 121,
#   'azimuth': 85,
#   'cloud_opacity': 8,
#   'period_end': datetime.datetime(2021, 7, 18, 10, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 127,
#   'azimuth': 89,
#   'cloud_opacity': 8,
#   'period_end': datetime.datetime(2021, 7, 18, 10, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 2,
#   'zenith': 133,
#   'azimuth': 93,
#   'cloud_opacity': 8,
#   'period_end': datetime.datetime(2021, 7, 18, 11, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 2,
#   'zenith': 139,
#   'azimuth': 98,
#   'cloud_opacity': 9,
#   'period_end': datetime.datetime(2021, 7, 18, 11, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 2,
#   'zenith': 145,
#   'azimuth': 104,
#   'cloud_opacity': 9,
#   'period_end': datetime.datetime(2021, 7, 18, 12, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 2,
#   'zenith': 151,
#   'azimuth': 111,
#   'cloud_opacity': 11,
#   'period_end': datetime.datetime(2021, 7, 18, 12, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 2,
#   'zenith': 157,
#   'azimuth': 121,
#   'cloud_opacity': 13,
#   'period_end': datetime.datetime(2021, 7, 18, 13, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 1,
#   'zenith': 162,
#   'azimuth': 135,
#   'cloud_opacity': 15,
#   'period_end': datetime.datetime(2021, 7, 18, 13, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 1,
#   'zenith': 165,
#   'azimuth': 157,
#   'cloud_opacity': 18,
#   'period_end': datetime.datetime(2021, 7, 18, 14, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 1,
#   'zenith': 166,
#   'azimuth': -175,
#   'cloud_opacity': 21,
#   'period_end': datetime.datetime(2021, 7, 18, 14, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 1,
#   'zenith': 164,
#   'azimuth': -149,
#   'cloud_opacity': 25,
#   'period_end': datetime.datetime(2021, 7, 18, 15, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 1,
#   'zenith': 160,
#   'azimuth': -130,
#   'cloud_opacity': 29,
#   'period_end': datetime.datetime(2021, 7, 18, 15, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 0,
#   'zenith': 155,
#   'azimuth': -117,
#   'cloud_opacity': 33,
# ...
#   'azimuth': -88,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 18, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 119,
#   'azimuth': -84,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 19, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 113,
#   'azimuth': -80,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 19, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 107,
#   'azimuth': -76,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 20, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 101,
#   'azimuth': -72,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 20, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 3,
#   'zenith': 95,
#   'azimuth': -68,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 21, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 4,
#   'ghi90': 4,
#   'ghi10': 1,
#   'ebh': 1,
#   'dni': 6,
#   'dni10': 0,
#   'dni90': 6,
#   'dhi': 3,
#   'air_temp': 4,
#   'zenith': 89,
#   'azimuth': -64,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 21, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 65,
#   'ghi90': 74,
#   'ghi10': 18,
#   'ebh': 22,
#   'dni': 129,
#   'dni10': 0,
#   'dni90': 224,
#   'dhi': 43,
#   'air_temp': 4,
#   'zenith': 84,
#   'azimuth': -60,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 22, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 141,
#   'ghi90': 159,
#   'ghi10': 39,
#   'ebh': 67,
#   'dni': 351,
#   'dni10': 4,
#   'dni90': 571,
#   'dhi': 74,
#   'air_temp': 4,
#   'zenith': 79,
#   'azimuth': -55,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 22, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 217,
#   'ghi90': 246,
#   'ghi10': 61,
#   'ebh': 116,
#   'dni': 421,
#   'dni10': 4,
#   'dni90': 668,
#   'dhi': 101,
#   'air_temp': 6,
#   'zenith': 74,
#   'azimuth': -49,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 23, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 289,
#   'ghi90': 327,
#   'ghi10': 81,
#   'ebh': 159,
#   'dni': 444,
#   'dni10': 3,
#   'dni90': 698,
#   'dhi': 130,
#   'air_temp': 6,
#   'zenith': 69,
#   'azimuth': -44,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 21, 23, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 353,
#   'ghi90': 399,
#   'ghi10': 98,
#   'ebh': 206,
#   'dni': 487,
#   'dni10': 2,
#   'dni90': 752,
#   'dhi': 147,
#   'air_temp': 7,
#   'zenith': 65,
#   'azimuth': -38,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 22, 0, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 407,
#   'ghi90': 460,
#   'ghi10': 112,
#   'ebh': 254,
#   'dni': 541,
#   'dni10': 2,
#   'dni90': 820,
#   'dhi': 153,
#   'air_temp': 7,
#   'zenith': 62,
#   'azimuth': -31,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 22, 0, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 446,
#   'ghi90': 509,
#   'ghi10': 120,
#   'ebh': 281,
#   'dni': 546,
#   'dni10': 2,
#   'dni90': 831,
#   'dhi': 165,
#   'air_temp': 8,
#   'zenith': 59,
#   'azimuth': -23,
#   'cloud_opacity': 12,
#   'period_end': datetime.datetime(2021, 7, 22, 1, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 472,
#   'ghi90': 544,
#   'ghi10': 123,
#   'ebh': 293,
#   'dni': 538,
#   'dni10': 2,
#   'dni90': 848,
#   'dhi': 179,
#   'air_temp': 8,
#   'zenith': 57,
#   'azimuth': -15,
#   'cloud_opacity': 13,
#   'period_end': datetime.datetime(2021, 7, 22, 1, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 483,
#   'ghi90': 564,
#   'ghi10': 120,
#   'ebh': 295,
#   'dni': 528,
#   'dni10': 2,
#   'dni90': 867,
#   'dhi': 188,
#   'air_temp': 8,
#   'zenith': 56,
#   'azimuth': -7,
#   'cloud_opacity': 14,
#   'period_end': datetime.datetime(2021, 7, 22, 2, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 477,
#   'ghi90': 569,
#   'ghi10': 111,
#   'ebh': 277,
#   'dni': 495,
#   'dni10': 2,
#   'dni90': 882,
#   'dhi': 200,
#   'air_temp': 9,
#   'zenith': 56,
#   'azimuth': 1,
#   'cloud_opacity': 16,
#   'period_end': datetime.datetime(2021, 7, 22, 2, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 459,
#   'ghi90': 559,
#   'ghi10': 98,
#   'ebh': 240,
#   'dni': 429,
#   'dni10': 2,
#   'dni90': 853,
#   'dhi': 219,
#   'air_temp': 9,
#   'zenith': 56,
#   'azimuth': 10,
#   'cloud_opacity': 18,
#   'period_end': datetime.datetime(2021, 7, 22, 3, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 429,
#   'ghi90': 534,
#   'ghi10': 83,
#   'ebh': 212,
#   'dni': 400,
#   'dni10': 2,
#   'dni90': 872,
#   'dhi': 217,
#   'air_temp': 9,
#   'zenith': 58,
#   'azimuth': 18,
#   'cloud_opacity': 19,
#   'period_end': datetime.datetime(2021, 7, 22, 3, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 390,
#   'ghi90': 495,
#   'ghi10': 69,
#   'ebh': 180,
#   'dni': 360,
#   'dni10': 0,
#   'dni90': 844,
#   'dhi': 210,
#   'air_temp': 9,
#   'zenith': 60,
#   'azimuth': 26,
#   'cloud_opacity': 21,
#   'period_end': datetime.datetime(2021, 7, 22, 4, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 343,
#   'ghi90': 442,
#   'ghi10': 56,
#   'ebh': 148,
#   'dni': 326,
#   'dni10': 0,
#   'dni90': 819,
#   'dhi': 195,
#   'air_temp': 8,
#   'zenith': 63,
#   'azimuth': 33,
#   'cloud_opacity': 22,
#   'period_end': datetime.datetime(2021, 7, 22, 4, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 289,
#   'ghi90': 376,
#   'ghi10': 44,
#   'ebh': 119,
#   'dni': 305,
#   'dni10': 0,
#   'dni90': 804,
#   'dhi': 170,
#   'air_temp': 8,
#   'zenith': 67,
#   'azimuth': 40,
#   'cloud_opacity': 23,
#   'period_end': datetime.datetime(2021, 7, 22, 5, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 231,
#   'ghi90': 302,
#   'ghi10': 33,
#   'ebh': 86,
#   'dni': 264,
#   'dni10': 0,
#   'dni90': 746,
#   'dhi': 145,
#   'air_temp': 8,
#   'zenith': 71,
#   'azimuth': 46,
#   'cloud_opacity': 24,
#   'period_end': datetime.datetime(2021, 7, 22, 5, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 167,
#   'ghi90': 219,
#   'ghi10': 23,
#   'ebh': 53,
#   'dni': 205,
#   'dni10': 0,
#   'dni90': 607,
#   'dhi': 114,
#   'air_temp': 8,
#   'zenith': 75,
#   'azimuth': 51,
#   'cloud_opacity': 24,
#   'period_end': datetime.datetime(2021, 7, 22, 6, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 101,
#   'ghi90': 132,
#   'ghi10': 14,
#   'ebh': 26,
#   'dni': 150,
#   'dni10': 0,
#   'dni90': 466,
#   'dhi': 75,
#   'air_temp': 7,
#   'zenith': 80,
#   'azimuth': 56,
#   'cloud_opacity': 24,
#   'period_end': datetime.datetime(2021, 7, 22, 6, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 38,
#   'ghi90': 50,
#   'ghi10': 4,
#   'ebh': 9,
#   'dni': 53,
#   'dni10': 0,
#   'dni90': 165,
#   'dhi': 29,
#   'air_temp': 7,
#   'zenith': 86,
#   'azimuth': 61,
#   'cloud_opacity': 24,
#   'period_end': datetime.datetime(2021, 7, 22, 7, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 7,
#   'zenith': 91,
#   'azimuth': 65,
#   'cloud_opacity': 24,
#   'period_end': datetime.datetime(2021, 7, 22, 7, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 7,
#   'zenith': 97,
#   'azimuth': 70,
#   'cloud_opacity': 24,
#   'period_end': datetime.datetime(2021, 7, 22, 8, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 103,
#   'azimuth': 74,
#   'cloud_opacity': 25,
#   'period_end': datetime.datetime(2021, 7, 22, 8, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 108,
#   'azimuth': 77,
#   'cloud_opacity': 25,
#   'period_end': datetime.datetime(2021, 7, 22, 9, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 115,
#   'azimuth': 81,
#   'cloud_opacity': 26,
#   'period_end': datetime.datetime(2021, 7, 22, 9, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 121,
#   'azimuth': 85,
#   'cloud_opacity': 28,
#   'period_end': datetime.datetime(2021, 7, 22, 10, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 127,
#   'azimuth': 89,
#   'cloud_opacity': 29,
#   'period_end': datetime.datetime(2021, 7, 22, 10, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 133,
#   'azimuth': 94,
#   'cloud_opacity': 30,
#   'period_end': datetime.datetime(2021, 7, 22, 11, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 139,
#   'azimuth': 99,
#   'cloud_opacity': 31,
#   'period_end': datetime.datetime(2021, 7, 22, 11, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 145,
#   'azimuth': 105,
#   'cloud_opacity': 33,
#   'period_end': datetime.datetime(2021, 7, 22, 12, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 151,
#   'azimuth': 112,
#   'cloud_opacity': 34,
#   'period_end': datetime.datetime(2021, 7, 22, 12, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 156,
#   'azimuth': 122,
#   'cloud_opacity': 36,
#   'period_end': datetime.datetime(2021, 7, 22, 13, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 161,
#   'azimuth': 136,
#   'cloud_opacity': 38,
#   'period_end': datetime.datetime(2021, 7, 22, 13, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 164,
#   'azimuth': 157,
#   'cloud_opacity': 39,
#   'period_end': datetime.datetime(2021, 7, 22, 14, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 165,
#   'azimuth': -176,
#   'cloud_opacity': 41,
#   'period_end': datetime.datetime(2021, 7, 22, 14, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 164,
#   'azimuth': -150,
#   'cloud_opacity': 42,
#   'period_end': datetime.datetime(2021, 7, 22, 15, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 160,
#   'azimuth': -131,
#   'cloud_opacity': 44,
#   'period_end': datetime.datetime(2021, 7, 22, 15, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 6,
#   'zenith': 155,
#   'azimuth': -119,
#   'cloud_opacity': 45,
#   'period_end': datetime.datetime(2021, 7, 22, 16, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 149,
#   'azimuth': -110,
#   'cloud_opacity': 46,
#   'period_end': datetime.datetime(2021, 7, 22, 16, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 143,
#   'azimuth': -103,
#   'cloud_opacity': 48,
#   'period_end': datetime.datetime(2021, 7, 22, 17, 0, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)},
#  {'ghi': 0,
#   'ghi90': 0,
#   'ghi10': 0,
#   'ebh': 0,
#   'dni': 0,
#   'dni10': 0,
#   'dni90': 0,
#   'dhi': 0,
#   'air_temp': 4,
#   'zenith': 137,
#   'azimuth': -97,
#   'cloud_opacity': 49,
#   'period_end': datetime.datetime(2021, 7, 22, 17, 30, tzinfo=<isodate.tzinfo.Utc object at 0x0000020B1C1950A0>),
#   'period': datetime.timedelta(seconds=1800)}]
